# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style
print('OK to proceed')
# Out:
# OK to proceed

# %%
df_bnb=pd.read_csv('listings.csv')
df_bnb.tail()
# Out:
#             id                                               name    host_id  \
# 7708  42959776  5'MINUTES STROLL TO RAFFLES PLACE, LAVISH 2-BR II  156409670
# 7709  42968514     SERENE 2BR. ON STEVENS RD./ W/D KING+TWIN BEDS  138649185
# 7710  42968688          SERENE STUDIO. ON STEVEN'S RD., SINGAPORE  138649185
# 7711  42970150  F1 Master Room with Private Bathroom Near City...   96467516
# 7712  42972584                 Lofty Suite in a Walk-up Apartment   43591543
#
#      host_name neighbourhood_group            neighbourhood  latitude  \
# 7708        Rj      Central Region            Downtown Core  1.281290
# 7709   Paridhi        North Region  Central Water Catchment  1.351036
# 7710   Paridhi      Central Region                  Tanglin  1.317094
# 7711     Sandy      Central Region                  Geylang  1.313395
# 7712    Claire      Central Region                  Geylang  1.314752
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 7708  103.848870  Entire home/apt    265              25                  0
# 7709  103.820588  Entire home/apt    430               6                  0
# 7710  103.825446  Entire home/apt    290               6                  0
# 7711  103.880143     Private room     91               2                  0
# 7712  103.900673  Entire home/apt    148               5                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 7708         NaN                NaN                              92
# 7709         NaN                NaN                              93
# 7710         NaN                NaN                              93
# 7711         NaN                NaN                              18
# 7712         NaN                NaN                              14
#
#       availability_365
# 7708               339
# 7709               364
# 7710               364
# 7711               264
# 7712               170

# %%
#let's check if the price dont have unrealistic value
df_bnb.sort_values(by='price', axis=0, ascending=False, inplace=True)
df_bnb.head(50)
# Out:
#             id                                               name    host_id  \
# 2609  20791161    YOUR entire PRIVATE LUXURY PENTHOUSE condo unit  122991242
# 2100  17831833                 Comfortable & Quiet Master Bedroom   68223771
# 3039  22617828       The Club Residences - Contemporary Manor (A)   84411185
# 1851  16395877           The Club Residences - Contemporary Manor   84411185
# 7684  42932845                EXQUISITE 2BR SUITE, SENTOSA ISLAND  156409670
# 4640  31604616                EXQUISITE 2BR SUITE, SENTOSA ISLAND  138649185
# 2421  19739630            Lakeside Master room of condo 裕廊湖畔公寓主人房  139204582
# 1164  11544732                                                  P   60916030
# 5761  36652759     [Rare] CORNER TERRACE UP FOR Rent (Whole unit)    5654051
# 4190  29549880    2-bedroom luxury penthouse + Jacuzzi + BBQ deck     800558
# 1370  13117403  Capella The Club Residences Singapore - Penthouse    9938906
# 1797  16155549   common room (3 minutes walking from MRT station)   91481229
# 1231  11994937                                   7 wonders hostel   64134757
# 1047  10343562                City 1 + 1 Bedroom Studio Apartment   53235451
# 4899  32909422                                         短租3个月 高级公寓  242184427
# 4624  31476831   Feb to Jul short term rental in sg, close to Mrt  235817515
# 2337  19218794  Renovated Master Bedroom & own bathroom@East C...   36416351
# 1593  14620083  Capella The Club Residences Singapore - 3 BR S...    9938906
# 6597  40236719           Luxurious stay like the Crazy Rich Asian   17404486
# 4188  29548473  2-bedroom luxury penthouse - 2 Jacuzzi's BBQ deck     800558
# 6597                    Grace      Central Region            Novena   1.33215
# 4188                  Kim (金)      Central Region            Rochor   1.31196
# 37                       Dara      Central Region           Tanglin   1.30292
# 4855                   Andrew      Central Region            Outram   1.28551
# 530                  Benedict   North-East Region           Hougang   1.37877
# 2596                    Zsolt      Central Region           Kallang   1.31404
# 6464                   Sujesh   North-East Region         Serangoon   1.35492
# 522                    JYidea      Central Region            Novena   1.31564
# 2787                   Darren      Central Region  Southern Islands   1.25046
# 6223                     Neha      Central Region   Singapore River   1.29545
# 402                       Max      Central Region           Geylang   1.31304
# 6631                     Jing      Central Region  Southern Islands   1.25746
# 4185                  Kim (金)      Central Region            Rochor   1.31180
# 4186                  Kim (金)      Central Region            Rochor   1.31164
# 5989                    A@Zml      Central Region   Singapore River   1.28925
# 4571                    Wrong      Central Region     Downtown Core   1.29479
# 4143                     Jing      Central Region  Southern Islands   1.25602
# 991                    Jerome      Central Region            Bishan   1.36412
# 3173                       皓婷      Central Region       Bukit Merah   1.28149
# 6370                   Andrea         East Region             Bedok   1.32808
# 1301                       子隆      Central Region           Geylang   1.31380
# 1243  Capella Club Residences      Central Region  Southern Islands   1.25040
# 7245                      Ray      Central Region            Bishan   1.34654
# 6287                  Paridhi      Central Region            Newton   1.31012
# 5720                       Rj      Central Region            Newton   1.30896
# 3895                      Ben         West Region       Bukit Batok   1.35835
# 5543                     Neha      Central Region           Kallang   1.29891
# 6488                  Mya The      Central Region            Rochor   1.30159
# 4184                  Kim (金)      Central Region            Rochor   1.31209
# 386                    Jia Yi         West Region          Clementi   1.31244
# 6484                       庄熙   North-East Region           Hougang   1.36710
# 6201                     Neha      Central Region   Singapore River   1.29425
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 2609  103.64656  Entire home/apt   9999               2                  5
# 2100  103.77181     Private room   9999               1                  1
# 3039  103.82551  Entire home/apt   8900               2                  0
# 1851  103.82225  Entire home/apt   8900               2                  0
# 7684  103.82532  Entire home/apt   8062               1                  0
# 4640  103.82482  Entire home/apt   8062               1                  0
# 2421  103.72569     Private room   7000               2                  0
# 1164  103.84135     Private room   7000               2                  5
# 5761  103.92176  Entire home/apt   5000             365                  0
# 4190  103.85394  Entire home/apt   4192               2                  0
# 1370  103.82392  Entire home/apt   4119               3                  0
# 1797  103.84897     Private room   4001               3                  0
# 1231  103.85881      Shared room   3770               1                  0
# 1047  103.85177  Entire home/apt   3499             365                  0
# 4899  103.85617     Private room   3299              60                  0
# 4624  103.77967  Entire home/apt   3199             150                  0
# 2337  103.91451     Private room   2999              90                 33
# 1593  103.82509  Entire home/apt   2943               1                  3
# 6597  103.82846  Entire home/apt   2888               2                  0
# 4188  103.85523  Entire home/apt   2717               2                  0
# 37    103.82253  Entire home/apt   2717               1                  1
# 4855  103.84112       Hotel room   2500               3                  0
# 530   103.88950  Entire home/apt   2300             365                  0
# 2596  103.84859  Entire home/apt   2173               4                  0
# 6464  103.86629  Entire home/apt   1800               1                  0
# 522   103.84075     Private room   1800               1                  0
# 2787  103.82529  Entire home/apt   1766               3                  1
# 6223  103.83250  Entire home/apt   1700               6                  0
# 402   103.87993  Entire home/apt   1600              90                  8
# 6631  103.81780     Private room   1579               1                  0
# 4185  103.85362  Entire home/apt   1491               2                  0
# 4186  103.85336  Entire home/apt   1491               2                  0
# 5989  103.84678  Entire home/apt   1479               1                  0
# 4571  103.85256  Entire home/apt   1455              35                  0
# 4143  103.82100     Private room   1361               1                  0
# 991   103.83146     Private room   1350               1                  0
# 3173  103.80889     Private room   1300               1                  0
# 6370  103.95081     Private room   1300             365                  0
# 1301  103.88099     Private room   1300               1                  0
# 1243  103.82539  Entire home/apt   1295               3                  1
# 7245  103.84211     Private room   1250              90                  0
# 6287  103.83853  Entire home/apt   1250               6                  0
# 5720  103.83847  Entire home/apt   1240               6                  1
# 3895  103.75945  Entire home/apt   1200               1                  2
# 5543  103.86099  Entire home/apt   1200               6                  0
# 6488  103.84752     Private room   1200               1                  0
# 4184  103.85357  Entire home/apt   1132               2                  0
# 386   103.75869      Shared room   1000               1                  0
# 6484  103.87755     Private room   1000               1                  3
# 6201  103.83224  Entire home/apt   1000               7                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 2609  2017-10-31               0.16                               1
# 2100  2017-05-27               0.03                               1
# 3039         NaN                NaN                               6
# 1851         NaN                NaN                               6
# 7684         NaN                NaN                              92
# 4640         NaN                NaN                              93
# 2421         NaN                NaN                               1
# 1164  2017-12-12               0.14                               1
# 5761         NaN                NaN                               1
# 4190         NaN                NaN                               6
# 1370         NaN                NaN                               4
# 1797         NaN                NaN                               1
# 1231         NaN                NaN                               1
# 1047         NaN                NaN                               1
# 4899         NaN                NaN                               1
# 4624         NaN                NaN                               1
# 2337  2018-03-31               0.99                               1
# 1593  2019-02-13               0.14                               4
# 6597         NaN                NaN                               1
# 4188         NaN                NaN                               6
# 37    2014-02-22               0.01                               1
# 4855         NaN                NaN                               5
# 530          NaN                NaN                               1
# 2596         NaN                NaN                               1
# 6464         NaN                NaN                               1
# 522          NaN                NaN                               1
# 2787  2018-11-21               0.06                               6
# 6223         NaN                NaN                              73
# 402   2017-09-21               0.13                               1
# 6631         NaN                NaN                               9
# 4185         NaN                NaN                               6
# 4186         NaN                NaN                               6
# 5989         NaN                NaN                               1
# 4571         NaN                NaN                               1
# 4143         NaN                NaN                               9
# 991          NaN                NaN                               1
# 3173         NaN                NaN                               1
# 6370         NaN                NaN                               2
# 1301         NaN                NaN                               1
# 1243  2016-08-25               0.02                               4
# 7245         NaN                NaN                               1
# 6287         NaN                NaN                              93
# 5720  2019-08-03               0.13                              92
# 3895  2019-05-19               0.18                               1
# 5543         NaN                NaN                              73
# 6488         NaN                NaN                               1
# 4184         NaN                NaN                               6
# 386          NaN                NaN                               1
# 6484  2020-01-26               0.65                               2
# 6201         NaN                NaN                              73
#
#       availability_365
# 2609                89
# 2100                 0
# 3039                 0
# 1851                48
# 7684               364
# 4640               364
# 2421                 0
# 1164               365
# 5761               365
# 4190               364
# 1370                18
# 1797               180
# 1231               365
# 1047                 0
# 4899                 0
# 4624                 0
# 2337                90
# 1593                49
# 6597               179
# 4188               364
# 37                   0
# 4855                 0
# 530                365
# 2596                 0
# 6464               364
# 522                 83
# 2787               139
# 6223               364
# 402                310
# 6631               365
# 4185               364
# 4186               364
# 5989               179
# 4571                89
# 4143                90
# 991                  0
# 3173                 0
# 6370               365
# 1301               365
# 1243                 0
# 7245                90
# 6287               364
# 5720               364
# 3895               178
# 5543               364
# 6488                90
# 4184               364
# 386                  0
# 6484                40
# 6201               364

# %%
#as the value above 1000 sgd will crush the other prices, let's drop them
df_bnb.reset_index().inplace=True

# %%
df_bnb.drop(df_bnb.index[:48], inplace=True)

# %%
#let's format our dataset a bit
df_bnb.rename(columns={'neighbourhood':'Neighborhood'}, inplace=True)
df_bnb[['Neighborhood']].head()
# Out:
#          Neighborhood
# 6484          Hougang
# 6201  Singapore River
# 1082          Kallang
# 6688          Geylang
# 579           Kallang

# %%
#Adding a column to better count the rows..
df_bnb['Count']=1
df_bnb['Count'].tail()
# Out:
# 3457    1
# 5894    1
# 5669    1
# 6069    1
# 2938    1
# Name: Count, dtype: int64

# %%
df_bnb[['Neighborhood','Count']].head()
# Out:
#          Neighborhood  Count
# 6484          Hougang      1
# 6201  Singapore River      1
# 1082          Kallang      1
# 6688          Geylang      1
# 579           Kallang      1

# %%
#let's regroup the neighborhood to have a aggregated view
df_co=df_bnb.groupby('Neighborhood',axis=0).mean()
df_co.reset_index(inplace=True)
df_co
# Out:
#                Neighborhood            id       host_id  latitude   longitude  \
# 0                Ang Mo Kio  2.262768e+07  8.311574e+07  1.375497  103.844110
# 1                     Bedok  1.975585e+07  8.327657e+07  1.319749  103.920088
# 2                    Bishan  2.296538e+07  6.928014e+07  1.354018  103.841162
# 3               Bukit Batok  1.997945e+07  7.563571e+07  1.355274  103.755695
# 4               Bukit Merah  2.807815e+07  9.931597e+07  1.279961  103.829815
# 5             Bukit Panjang  2.681765e+07  1.154396e+08  1.369396  103.769134
# 6               Bukit Timah  2.174976e+07  7.987941e+07  1.323241  103.791020
# 7   Central Water Catchment  3.385982e+07  1.322373e+08  1.351952  103.820104
# 8             Choa Chu Kang  1.971114e+07  7.843414e+07  1.387012  103.750735
# 9                  Clementi  2.613121e+07  1.150548e+08  1.308813  103.762758
# 10            Downtown Core  2.887960e+07  1.035163e+08  1.280282  103.848898
# 11                  Geylang  2.669007e+07  1.044141e+08  1.313163  103.884072
# 12                  Hougang  2.477109e+07  8.957846e+07  1.362550  103.886364
# 13              Jurong East  2.842858e+07  1.223879e+08  1.336660  103.739503
# 14              Jurong West  2.394672e+07  1.116674e+08  1.343831  103.708438
# 15                  Kallang  2.760241e+07  1.051992e+08  1.314124  103.860997
# 16                   Mandai  9.744111e+06  4.752603e+07  1.425665  103.825750
# 17             Marina South  3.351194e+07  2.350512e+08  1.284215  103.861810
# 24   98.186441       71.355932          14.423729           0.935667
# 25  304.000000        1.000000           0.000000                NaN
# 26   82.060606       13.606061          20.787879           1.779500
# 27  146.141129       33.282258           5.076613           0.585736
# 28  170.136364       11.197861          22.294118           1.138855
# 29  161.007692        7.953846          20.001923           1.523554
# 30   78.637931       22.465517           2.310345           0.235517
# 31   88.914894       38.659574          11.170213           0.983077
# 32   93.602740       21.589041          24.904110           1.070400
# 33  179.307692        9.041026           7.589744           0.615042
# 34  414.000000        6.823529           4.764706           1.188571
# 35  111.400000        1.000000          83.000000           2.422500
# 36   94.367647       24.308824          38.411765           1.420833
# 37  202.692308       16.840237          15.130178           1.415536
# 38  122.367521       24.384615           9.230769           0.658983
# 39   52.333333      121.666667          10.000000           0.350000
# 40   78.225352       39.591549          10.464789           0.741591
# 41  123.135135       23.378378          10.378378           0.917059
#
#     calculated_host_listings_count  availability_365  Count
# 0                         2.120000        149.300000    1.0
# 1                        19.545741        186.504732    1.0
# 2                        49.711864        167.559322    1.0
# 3                         1.631579        172.508772    1.0
# 4                        28.417143        205.654286    1.0
# 5                         1.931034        136.724138    1.0
# 6                        11.528000        162.640000    1.0
# 7                       148.777778        205.111111    1.0
# 8                         1.762712        131.644068    1.0
# 9                        52.041667        208.958333    1.0
# 10                      107.503937        215.098425    1.0
# 11                       57.677778        214.141111    1.0
# 12                        5.884615        183.605769    1.0
# 13                      102.318182        192.022727    1.0
# 14                       13.895105        180.377622    1.0
# 15                       59.468835        253.876242    1.0
# 16                        2.000000        363.500000    1.0
# 17                        8.000000         90.000000    1.0
# 18                       29.806250        159.718750    1.0
# 19                       48.642857        224.571429    1.0
# 20                       23.018018        219.639640    1.0
# 21                       64.844523        261.544170    1.0
# 22                       23.601449        264.985507    1.0
# 23                       42.213389        230.018828    1.0
# 24                        1.254237        154.016949    1.0
# 25                        1.000000        365.000000    1.0
# 26                        1.151515        117.272727    1.0
# 27                       40.790323        212.584677    1.0
# 28                       39.852941        247.451872    1.0
# 29                       37.276923        236.053846    1.0
# 30                        5.224138        276.500000    1.0
# 31                        1.234043        137.489362    1.0
# 32                       11.506849        149.575342    1.0
# 33                       39.933333        268.569231    1.0
# 34                        8.647059        250.411765    1.0
# 35                        3.400000        357.200000    1.0
# 36                        3.044118        150.220588    1.0
# 37                       30.106509        182.828402    1.0
# 38                       53.034188        205.025641    1.0
# 39                        1.333333        213.000000    1.0
# 40                        2.211268        204.492958    1.0
# 41                        2.594595        213.054054    1.0

# %%
#let's reformat the prices to weight them with the number of occurence (average price per neighborhood)
df_co['average_price']=(df_co['price']/df_co['Count']).round(2)
df_co['average_price'].head()
# Out:
# 0     81.56
# 1    122.55
# 2    131.02
# 3     91.61
# 4    143.11
# Name: average_price, dtype: float64

# %%
#let's check if the avg prices make sense
df_co['average_price'].min()
# Out:
# 43.0

# %%
df_co['average_price'].max()
# Out:
# 449.0

# %%
df_co['average_price'].dtype
# Out:
# dtype('float64')

# %%
df_co['average_price'] = df_co['Neighborhood']+': $' + df_co['average_price'].astype(str)
df_co.head(10)
# Out:
#               Neighborhood            id       host_id  latitude   longitude  \
# 0               Ang Mo Kio  2.262768e+07  8.311574e+07  1.375497  103.844110
# 1                    Bedok  1.975585e+07  8.327657e+07  1.319749  103.920088
# 2                   Bishan  2.296538e+07  6.928014e+07  1.354018  103.841162
# 3              Bukit Batok  1.997945e+07  7.563571e+07  1.355274  103.755695
# 4              Bukit Merah  2.807815e+07  9.931597e+07  1.279961  103.829815
# 5            Bukit Panjang  2.681765e+07  1.154396e+08  1.369396  103.769134
# 6              Bukit Timah  2.174976e+07  7.987941e+07  1.323241  103.791020
# 7  Central Water Catchment  3.385982e+07  1.322373e+08  1.351952  103.820104
# 8            Choa Chu Kang  1.971114e+07  7.843414e+07  1.387012  103.750735
# 9                 Clementi  2.613121e+07  1.150548e+08  1.308813  103.762758
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0   81.560000       19.400000           3.640000           0.761600
# 1  122.548896       19.630915          17.296530           0.845826
# 2  131.016949       26.915254          12.830508           0.826176
# 3   91.614035       42.122807           5.157895           0.385455
# 4  143.105714       14.722857          11.622857           0.943288
# 5   85.793103       20.517241          11.655172           0.926471
# 6  135.480000       24.760000          11.632000           0.594048
# 7  197.814815       17.148148           4.333333           0.481111
# 8   76.389831       20.203390          18.322034           0.987750
# 9  182.316667       36.500000           3.991667           0.585167
#
#    calculated_host_listings_count  availability_365  Count  \
# 0                        2.120000        149.300000    1.0
# 1                       19.545741        186.504732    1.0
# 2                       49.711864        167.559322    1.0
# 3                        1.631579        172.508772    1.0
# 4                       28.417143        205.654286    1.0
# 5                        1.931034        136.724138    1.0
# 6                       11.528000        162.640000    1.0
# 7                      148.777778        205.111111    1.0
# 8                        1.762712        131.644068    1.0
# 9                       52.041667        208.958333    1.0
#
#                     average_price
# 0                Ang Mo Kio$81.56
# 1                    Bedok$122.55
# 2                   Bishan$131.02
# 3               Bukit Batok$91.61
# 4              Bukit Merah$143.11
# 5             Bukit Panjang$85.79
# 6              Bukit Timah$135.48
# 7  Central Water Catchment$197.81
# 8             Choa Chu Kang$76.39
# 9                 Clementi$182.32

# %%
#we have a nice 1:10 relation between the min and max, we will be able to slice the map in  5 color intensity using a 2 scale
df_co
# Out:
#                Neighborhood            id       host_id  latitude   longitude  \
# 0                Ang Mo Kio  2.262768e+07  8.311574e+07  1.375497  103.844110
# 1                     Bedok  1.975585e+07  8.327657e+07  1.319749  103.920088
# 2                    Bishan  2.296538e+07  6.928014e+07  1.354018  103.841162
# 3               Bukit Batok  1.997945e+07  7.563571e+07  1.355274  103.755695
# 4               Bukit Merah  2.807815e+07  9.931597e+07  1.279961  103.829815
# 5             Bukit Panjang  2.681765e+07  1.154396e+08  1.369396  103.769134
# 6               Bukit Timah  2.174976e+07  7.987941e+07  1.323241  103.791020
# 7   Central Water Catchment  3.385982e+07  1.322373e+08  1.351952  103.820104
# 37                       30.106509        182.828402    1.0
# 38                       53.034188        205.025641    1.0
# 39                        1.333333        213.000000    1.0
# 40                        2.211268        204.492958    1.0
# 41                        2.594595        213.054054    1.0
#
#                      average_price
# 0                 Ang Mo Kio$81.56
# 1                     Bedok$122.55
# 2                    Bishan$131.02
# 3                Bukit Batok$91.61
# 4               Bukit Merah$143.11
# 5              Bukit Panjang$85.79
# 6               Bukit Timah$135.48
# 7   Central Water Catchment$197.81
# 8              Choa Chu Kang$76.39
# 9                  Clementi$182.32
# 10            Downtown Core$200.16
# 11                  Geylang$158.26
# 12                  Hougang$119.45
# 13              Jurong East$130.98
# 14               Jurong West$77.92
# 15                  Kallang$129.62
# 16                     Mandai$43.0
# 17              Marina South$449.0
# 18            Marine Parade$142.83
# 19                   Museum$199.03
# 20                   Newton$176.49
# 21                   Novena$168.23
# 22                  Orchard$313.36
# 23                   Outram$128.23
# 24                 Pasir Ris$98.19
# 25                   Pioneer$304.0
# 26                   Punggol$82.06
# 27               Queenstown$146.14
# 28             River Valley$170.14
# 29                   Rochor$161.01
# 30                 Sembawang$78.64
# 31                  Sengkang$88.91
# 32                  Serangoon$93.6
# 33          Singapore River$179.31
# 34          Southern Islands$414.0
# 35              Sungei Kadut$111.4
# 36                  Tampines$94.37
# 37                  Tanglin$202.69
# 38                Toa Payoh$122.37
# 39   Western Water Catchment$52.33
# 40                 Woodlands$78.23
# 41                   Yishun$123.14

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
# Folium installed and imported!

# %%
#a quick google search gives us the location of Singapore
latitude = 1.3521
longitude = 103.8198

# %%
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/world_countries.json -O map.geojson
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
#lets check whether we are righlty centered on Singapore
singap = r'world_countries.json' # geojson file

sg_map1 = folium.Map(location=[latitude, longitude], zoom_start=12)
sg_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#let's apply the choropleth procedure (not working for now as i cannot find the right json file)
threshold_scale = np.linspace(df_co['average_price'].min(),
                              df_co['average_price'].max(),
                              5, dtype=int)
threshold_scale = threshold_scale.tolist() # change the numpy array to a list
threshold_scale[-1] = threshold_scale[-1] + 1 # make sure that the last value of the list is greater than the maximum immigration

sg_map2 = folium.Map(location=[latitude, longitude], zoom_start=12, tiles='Mapbox Bright')
sg_map2.choropleth(
    geo_data=singap,
    data=df_co,
    columns=['Neighborhood', 'average_price'],
    key_on='feature.properties.name',
    threshold_scale=threshold_scale,
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average price for Air BNB per district',
    reset=True
)
sg_map2
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-24-81aed5d0e9b4> in <module>
#       2 threshold_scale = np.linspace(df_co['average_price'].min(),
#       3                               df_co['average_price'].max(),
# ----> 4                               5, dtype=int)
#       5 threshold_scale = threshold_scale.tolist() # change the numpy array to a list
#       6 threshold_scale[-1] = threshold_scale[-1] + 1 # make sure that the last value of the list is greater than the maximum immigration
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     127     # Convert float/complex array scalars to float, gh-3504
#     128     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 129     start = asanyarray(start) * 1.0
#     130     stop  = asanyarray(stop)  * 1.0
#     131
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
sg_map3 = folium.Map(location=[latitude, longitude], zoom_start=12)

# %%
#we can display the average price per neighborhood
sg_map = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lng, label in zip(df_co.latitude, df_co.longitude, df_co.average_price):
    folium.features.CircleMarker(
        [lat, lng],
        radius=7,
        color='blue',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.4
    ).add_to(sg_map3)

sg_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
